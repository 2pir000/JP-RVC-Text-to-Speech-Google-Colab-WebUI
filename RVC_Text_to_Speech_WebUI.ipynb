# %% [markdown]
# <a href="https://colab.research.google.com/github/2pir000/JP-RVC-Text-to-Speech-Google-Colab-WebUI/blob/main/RVC_Text_to_Speech_WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 順番にやってってください
# （左側の再生ボタンを押すとコードが実行できます）

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# 基本、ここからの実行したコードのログで
# RESTART RUNTIME みたいなボタンが出てきても押さなくて大丈夫です

# %%
# !pip install asyncio
# !pip install datetime
# !pip install logging
# !pip install os
# !pip install time
# !pip install traceback
# !pip install edge_tts
# !pip install gradio
# !pip install librosa
# !pip install torch
# !pip install fairseq
# !pip install checkpoint_utils
# !pip install faiss
# !pip install torchcrepe

# %%
# !git clone https://github.com/litagin02/rvc-tts-webui.git

# %%
cd rvc-tts-webui

# %%
# !curl -L -O https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/hubert_base.pt
# !curl -L -O https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/rmvpe.pt

# %%
# !apt install python3.10-venv

# %%
# !python -m venv venv

# %%
file_name = "/content/rvc-tts-webui/requirements.txt"

with open(file_name, encoding="cp932") as f:
    data_lines = f.read()

data_lines = data_lines.replace("pyworld==0.3.3", "pyworld==0.3.2")

with open(file_name, mode="w", encoding="cp932") as f:
    f.write(data_lines)

# %%
file_name = "/content/rvc-tts-webui/requirements.txt"

with open(file_name, encoding="cp932") as f:
    data_lines = f.read()

data_lines = data_lines.replace("app.launch(inbrowser=True)", "app.launch(inbrowser=True,share=True)")

with open(file_name, mode="w", encoding="cp932") as f:
    f.write(data_lines)

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ここで"rvc-tts-webui"内の"weights"フォルダー内に"model1"等、半角英数字でサブフォルダーを作り、RVCの学習データ（indexファイル、pthファイル）をアップロードしてください
# （アップロード画面は左端のツールバーにあるフォルダーアイコンから開けます）

# %%
# !python /content/rvc-tts-webui/app.py --port 41130

# %% [markdown]
# rmvpe model loaded.と Running on local URL:が出たら成功です。
# Running on public URL:のすぐ隣に出力されているURLをクリックして、WebUIを起動してください！
